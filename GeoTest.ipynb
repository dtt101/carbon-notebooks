# %% [markdown]
# # Visualising output over time
#
# A test notebook to explore ways of visualising data over time per group

# %%
# Import data
import pandas as pd

df = pd.read_excel('la-geo/pcan_data.xlsx', sheet_name='2019', header=3)

df.describe()
# Out:
#               Year       Total  ...  (18, 'Changes in inventories')    population
# count   353.000000  353.000000  ...                      353.000000  3.530000e+02
# mean   2018.671388   12.708621  ...                       84.675191  6.731765e+05
# std       1.906837    1.009151  ...                      543.770938  4.334593e+06
# min    2002.000000   10.307216  ...                        0.261909  2.153000e+03
# 25%    2019.000000   11.972693  ...                       11.722199  9.668600e+04
# 50%    2019.000000   12.727008  ...                       16.474780  1.315560e+05
# 75%    2019.000000   13.308906  ...                       29.150239  2.219160e+05
# max    2022.000000   18.735303  ...                     7663.665110  6.109483e+07
#
# [8 rows x 198 columns]
