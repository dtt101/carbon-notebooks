# %% [markdown]
# # Visualising output over time
#
# A test notebook to explore ways of visualising data over time per group

# %%
# Import data
import pandas as pd

df = pd.read_excel('la-geo/pcan_data.xlsx', sheet_name='2019', header=3)

df.head(3)
# Out:
#    Year Country Devolved region Government Office Region Local Authority  \
# 0  2019      UK             NaN                      NaN             NaN
# 1  2019      UK         England                      NaN             NaN
# 2  2019      UK        Scotland                      NaN             NaN
#
#   Local Authority Code      Total      Food   Housing  Transport  ...  \
# 0                  NaN  12.409224  1.267340  2.714203   3.221576  ...
# 1                  NaN  12.498722  1.266189  2.739428   3.235624  ...
# 2                  NaN  12.010059  1.261484  2.914407   2.951679  ...
#
#    ('12.5.5', 'Other insurance')  \
# 0                     639.450552
# 1                     525.261782
# 2                      55.415553
#
#    ('12.6.2', 'Other financial services n.e.c.')  \
# 0                                     251.762415
# 1                                     216.509542
# 2                                      21.249102
#
#    ('12.7.1', 'Other services n.e.c.')  \
# 0                          1144.350716
# 1                          1088.350808
# 2                            32.163325
#
#    (13, 'Non-profit instns serving households')  (14, 'Central\r government')  \
# 0                                   4641.744627                  40513.530131
# 1                                   3900.189386                  34041.174793
# 2                                    378.558449                   3304.089383
#
#    (15, 'Local\r Authorities')  (16, 'Gross fixed\r capital\r formation')  \
# 0                 24951.304680                               97746.591923
# 1                 20965.137355                               82130.804456
# 2                  2034.908847                                7971.743651
#
#    (17, 'Valuables')  (18, 'Changes in inventories')  population
# 0        2062.699899                     7663.665110    61094828
# 1        1733.167354                     6439.334284    51345457
# 2         168.223920                      625.011803     5062011
#
# [3 rows x 203 columns]

# %%
# Bar chart of total emissions for the UK
import matplotlib.pyplot as plt
import seaborn as sns

ukwide = df.iloc[0, [7, 8, 9, 10, 11, 12]]
fig = sns.barplot(x=ukwide.index, y=ukwide.values)
fig.set_xticklabels(fig.get_xticklabels(), rotation=45, horizontalalignment='right')
fig.set(xlabel='Category', ylabel='Total (per capita tonnes)', title='UK Emissions 2019, by category')
plt.show()
